# %%
# !pip install sentence_transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.8 MB/s eta 0:00:00
# ...

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/Авалон/Диплом/data')

# %%
sentences = ["привет мир", "hello world", "здравствуй вселенная"]
embeddings = model.encode(sentences)
# print(embeddings)

# %%
a = embeddings[1]
b = embeddings[2]
cos_sim = dot (a, b)/( norm (a)* norm (b))
cos_sim
# Out:
# 0.8280481

# %%
# 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2' - 768

model = SentenceTransformer('cointegrated/rubert-tiny2')
coffee = pd.read_csv('coffee.csv')

# %%
sentences = pd.read_csv('sentences.csv')
sentences.shape
# Out:
# (605102, 3)

# %%
# %%time
b = pd.DataFrame(map(model.encode, sentences['text'].iloc[:1000]))
b.head()
# Out:
# CPU times: user 9.22 s, sys: 37.5 ms, total: 9.25 s
# Wall time: 9.32 s
#         0         1         2         3         4         5         6    \
# 0  0.048476 -0.006646  0.071841 -0.093770 -0.030067 -0.018061  0.034320
# 1  0.082850  0.029536 -0.015753 -0.125323 -0.038115  0.025186 -0.058192
# 2 -0.043757  0.021217 -0.028397 -0.069249  0.026357  0.023920 -0.015558
# 3 -0.074883  0.026578  0.014243 -0.119580  0.011328  0.021014 -0.011697
# 4 -0.039896 -0.010953  0.019155 -0.058727  0.004631  0.061589 -0.027364
#
#         7         8         9    ...       302       303       304       305  \
# 0 -0.030851 -0.075158 -0.015608  ...  0.047531 -0.002922 -0.001268  0.001228
# 1 -0.053910 -0.058186 -0.001935  ...  0.012691 -0.015350  0.022114  0.039686
# 2  0.040155  0.000685 -0.009317  ...  0.013883 -0.061593 -0.071101  0.037206
# 3 -0.069071 -0.014877 -0.073264  ...  0.060560 -0.094814 -0.000250  0.050939
# 4 -0.012156 -0.084530 -0.014900  ...  0.003364  0.068936 -0.005096 -0.028384
# ...

# %%
# %%time
result = pd.DataFrame(sentences['text'].iloc[:1000].apply(lambda x: model.encode(x)).to_list())
# Out:
# CPU times: user 8.57 s, sys: 26.9 ms, total: 8.59 s
# Wall time: 8.62 s

# %%
tiny_1 = pd.read_csv('coffee_rubert-tiny2_312.csv')

# %%
tiny_1.shape
# Out:
# (26207, 312)
